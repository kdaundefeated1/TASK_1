# %% [markdown]
# ## TASK 1

# %% [markdown]
# ## Question 1

# %%
james_scores = [78,90,67,52,84] #Q1 (a)

# %%
james_scores.sort()

# %%
print(james_scores)
# Out:
# [52, 67, 78, 84, 90]

# %%
highest = james_scores[4] #Q2(b) James' highest score

# %%
print(highest)
# Out:
# 90

# %%
lowest = james_scores[0] #James' lowest score

# %%
print(lowest)
# Out:
# 52

# %%
total = sum(james_scores) #Q1(C)

# %%
print(total)
# Out:
# 371

# %%
length = len(james_scores)

# %%
print(length)
# Out:
# 5

# %%
average = total/length

# %%
print(average) #Final answer for Q1(c)
# Out:
# 74.2

# %%
print(f"James's best score is {highest}, and his lowest score is {lowest}. His average score is {average}") #Q1(d)
# Out:
# James's best score is 90, and his lowest score is 52. His average score is 74.2

# %% [markdown]
# ## Question 2

# %%
amount = [1200,1000,450,780,870,1100,1500] #Q2(a)

# %%
amount.sort()

# %%
print(amount)
# Out:
# [450, 780, 870, 1000, 1100, 1200, 1500]

# %%
amount[6] #Q2(b) Most expensive amount.
# Out:
# 1500

# %%
amount[0] #Q2(c) Least expensive amount.
# Out:
# 450

# %%
amount[-3:] #Q2(d) The three most expensive amounts
# Out:
# [1100, 1200, 1500]

# %% [markdown]
# ## Question 3

# %%
items= ["clothes","shoes","toiletries","snacks","umbrella"] #Q3(a)

# %%
print(items)
# Out:
# ['clothes', 'shoes', 'toiletries', 'snacks', 'umbrella']

# %%
items.remove("snacks") #Q3(b)

# %%
print(items)
# Out:
# ['clothes', 'shoes', 'toiletries', 'umbrella']

# %%
items.insert(0,"sunglasses") #Q3(c)

# %%
print(items)
# Out:
# ['sunglasses', 'clothes', 'shoes', 'toiletries', 'umbrella']

# %%
final_list = items #Q3(d) Uncle Joe's final packing list.

# %%
print(final_list)
# Out:
# ['sunglasses', 'clothes', 'shoes', 'toiletries', 'umbrella']

# %% [markdown]
# ## Question 4

# %%
allen = ("Allen James",17,"Mechanical Engineering",4.0)

# %%
allen[0] #Q3(a) printing the name Allen James using indexing.
# Out:
# 'Allen James'

# %%
allen[2] #Q3(a) printing the department, Mechanical Engineering using indexing.
# Out:
# 'Mechanical Engineering'

# %%
allen[3] = 3.8 #Q3(b) We encountered a TypeError. This is because tuples are immutable.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 allen[3] = 3.8
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Q3(c). The data type used for her GPA is a float.
#        The data type is not an integer because, integers do not have decimals.
